# %% [markdown]
# ###  Scenario 1: Grocery Shopping List
# You are creating a program to manage a grocery shopping list. Users should be able to add items,
# remove items, and display the current list.

# %%
# Initialize an empty grocery shopping list as a dictionary
shopping_list = {}

# Function to display the current list
def display_list():
    if not shopping_list:
        print("Your shopping list is empty.")
    else:
        print("Your current shopping list:")
        for item, quantity in shopping_list.items():
            print(f"{item}: {quantity}")

# Function to add items to the list
def add_item():
    item = input("Enter the item to add: ")
    quantity = int(input("Enter the quantity: "))

    if item in shopping_list:
        shopping_list[item] += quantity
    else:
        shopping_list[item] = quantity

    print(f"{quantity} {item}(s) added to the shopping list.")

# Function to remove items from the list
def remove_item():
    item = input("Enter the item to remove: ")

    if item in shopping_list:
        quantity = int(input("Enter the quantity to remove: "))

        if quantity >= shopping_list[item]:
            del shopping_list[item]
        else:
            shopping_list[item] -= quantity

        print(f"{quantity} {item}(s) removed from the shopping list.")
    else:
        print(f"{item} not found in the shopping list.")

# Main loop for user interaction
while True:
    print("\nMenu:")
    print("1. Display current list")
    print("2. Add or update item to the list")
    print("3. Remove item from the list")
    print("4. Exit")

    choice = input("Enter your choice (1-4): ")

    if choice == "1":
        display_list()
    elif choice == "2":
        add_item()
    elif choice == "3":
        remove_item()
    elif choice == "4":
        print("Exiting the program.")
        break
    else:
        print("Invalid choice. Please enter a number between 1 and 4.")
# Out:
# Menu:
# 1. Display current list
# 2. Add or update item to the list
# 3. Remove item from the list
# 4. Exit
# Enter your choice (1-4): 2
# Enter the item to add: Mango
# Enter the quantity: 6
# 6 Mango(s) added to the shopping list.
#
# Menu:
# 1. Display current list
# 2. Add or update item to the list
# 3. Remove item from the list
# 4. Exit
# Enter your choice (1-4): 2
# Enter the item to add: Apple
# Enter the quantity: 4
# 4 Apple(s) added to the shopping list.
#
# Menu:
# 1. Display current list
# 2. Add or update item to the list
# 3. Remove item from the list
# 4. Exit
# Enter your choice (1-4): 3
# Enter the item to remove: Mango
# Enter the quantity to remove: 6
# 6 Mango(s) removed from the shopping list.
#
# Menu:
# 1. Display current list
# 2. Add or update item to the list
# 3. Remove item from the list
# 4. Exit
# Enter your choice (1-4): 1
# Your current shopping list:
# Apple: 4
#
# Menu:
# 1. Display current list
# 2. Add or update item to the list
# 3. Remove item from the list
# 4. Exit
# Enter your choice (1-4): 4
# Exiting the program.

# %% [markdown]
# ###  Scenario 2: Student Grades
# You are managing student grades using a dictionary. You need to calculate the average grade.take
# atleast 5 Students grades & then calculate the average.

# %%
# Dictionary to store the students grade
student_grades = {}

# Inputs at least 5 students grade
num_students = 5
for i in range(num_students):
    student_name = input(f"Enter the Name of Student {i + 1}: ")
    while True:
        try:
            grade = float(input(f"Enter the grade for {student_name}: "))
            if 0 <= grade <= 100:
                student_grades[student_name] = grade
                break
            else:
                print("Invalid grade. Please enter a number between 0 and 100.")
        except ValueError:
            print("Invalid input. Please enter a numeric grade")

# Function to calculate the average grade
def calculate_average(grades):
    if not grades:
        return 0
    total = sum(grades.values())
    return total/len(grades)

# Calculate and display the average grade
average_grade = calculate_average(student_grades)
print(f"\nAverage Grade: {average_grade:.2f}")
# Out:
# Enter the Name of Student 1: Umair
# Enter the grade for Umair: 88
# Enter the Name of Student 2: Noman
# Enter the grade for Noman: 78
# Enter the Name of Student 3: Salman
# Enter the grade for Salman: 86
# Enter the Name of Student 4: Arsalan
# Enter the grade for Arsalan: 92
# Enter the Name of Student 5: Niaz
# Enter the grade for Niaz: 83
#
# Average Grade: 85.40

# %% [markdown]
# ###  Scenario 3: Word Frequency Counter
# You are given a list of words, and you need to count the frequency of each word.
# word_list = ["apple", "banana", "apple", "orange", "banana", "grape", "apple"]

# %%
word_list = ["apple", "banana", "apple", "orange", "banana", "grape", "apple"]

#Dictionary to store word frequencies
word_frequencey = {}

#count the frequency of each word
for word in word_list:
    if word in word_frequencey:
        word_frequencey[word] += 1
    else:
        word_frequencey[word] = 1
        
#display Frequency
print("Word Frequencies: ")
for word, frequency in word_frequencey.items():
    print(f"{word}: {frequency}")
# Out:
# Word Frequencies:
# apple: 3
# banana: 2
# orange: 1
# grape: 1

# %% [markdown]
# ###  Scenario 4: Password Strength Checker
# You are creating a program to check the strength of passwords based on certain criteria.
# • Password should be at least 8 characters long.
# • Password should contain at least one digit.
# • Password should contain at least one letter.

# %%
print("Criteria:")
print("• Password should be at least 8 characters long")
print("• Password should contain at least one digit")
print("• Password should contain at least one letter")

password = input("Enter Password: ")

if len(password) >= 8:
    if any(char.isdigit() for char in password) and any(char.isalpha() for char in password):
        print("Password is Strong.")
    else:
        print("password is Weak, Please fullfil the Criteria.")
else:
    print("password is Weak, Please fullfil the Criteria.")
    
another_password = input("Do you want to check another password? (yes/no): ").lower()
if another_password != 'yes':
    print("Exiting the program.")

if another_password == 'yes':
    password = input("Enter Password: ")
    
if len(password) >= 8:
    if any(char.isdigit() for char in password) and any(char.isalpha() for char in password):
        print("Password is Strong.")
    else:
        print("password is Weak, Please fullfil the Criteria.")
else:
    print("password is Weak, Please fullfil the Criteria.")
# Out:
# Criteria:
# • Password should be at least 8 characters long
# • Password should contain at least one digit
# • Password should contain at least one letter
# Enter Password: umair
# password is Weak, Please fullfil the Criteria.
# Do you want to check another password? (yes/no): yes
# Enter Password: Umair675
# Password is Strong.

# %% [markdown]
# ### Scenario 05: Voting System (Annual Employee Recognition Awards)
# You are developing a simple voting system for a contest. Users can vote for their Favorite option, and
# you need to count the votes.
# In a corporate setting, the HR department is organizing the Annual Employee Recognition Awards,
# where employees get the opportunity to vote for their colleagues nominated in different categories.
# The HR team has decided to use a simple voting system to collect and tally votes for the nominees in
# various award categories. The script provided will be utilized for this purpose.
# Candidates: The nominees for different award categories, such as "Employee of the Year," "Team
# Player of the Year," and "Innovation Award," are represented by the list of candidates: 'Candidate A,'
# 'Candidate B,' and 'Candidate C.'
# Voting Process: Employees are requested to input the number of voters participating in the awards.
# Each voter is presented with a list of nominees, and they can vote for their preferred candidate by
# entering the corresponding number.
# Validation: The script ensures that the entered vote is within the valid range of candidates. If an
# employee enters an invalid vote, the system prompts them to choose a valid candidate.
# Recording Votes: The script records each vote for the selected candidate and prints a confirmation
# message indicating that the vote has been recorded.
# Results Display: Once all votes are collected, the system displays the voting results, showing the
# number of votes each candidate received in each category.
# Award Winners: Based on the voting results, the HR department can identify the winners for each
# award category and proceed with recognizing and rewarding the selected employees during the
# Annual Employee Recognition Ceremony.
# This script provides a straightforward and transparent way for employees to participate in the
# recognition process, fostering a sense of engagement and community within the organization. The
# HR team can use the collected votes to acknowledge and appreciate the efforts of outstanding
# employees in various aspects of their work.

# %%
candidates = ['Candidate A', 'Candidate B', 'Candidate C']


votes = {candidate: 0 for candidate in candidates}

def user_input():
    print("\nMenu:")
    for number, candidate in enumerate(candidates, start=1):
        print(f"{number}. {candidate}")
        
    while True:
        try:
            vote = int(input("Enter vote for candidate : "))
            if 1 <= vote <= len(candidates):
                return candidates[vote - 1]
            else:
                print("Invalid Number, Please Choose a Valid Candidate.")
        except:
            print("Invalid Input, Please Enter a Number.")
    
while True:
    try:
        voters = int(input("Enter the Number of Voters: "))
        if voters > 0:
            break
        else:
            print("Number of voters must be greater than 0.")
    except:
        print("Invalid Input. Please Enter a Number.")
        
#process
for num_voter in range(voters):
    print(f"\nVoter: {num_voter}:")
    choosen_candidate = user_input()
    votes[choosen_candidate] += 1
    print(f"Vote Recorded for {choosen_candidate}.\n")
    
#display Result
print("Final Result:")
for candidate, vote_count in votes.items():
    print(f"{candidate}: {vote_count} votes")
# Out:
# Enter the Number of Voters: 4
#
# Voter: 0:
#
# Menu:
# 1. Candidate A
# 2. Candidate B
# 3. Candidate C
# Enter vote for candidate : 2
# Vote Recorded for Candidate B.
#
#
# Voter: 1:
#
# Menu:
# 1. Candidate A
# 2. Candidate B
# 3. Candidate C
# Enter vote for candidate : 3
# Vote Recorded for Candidate C.
#
#
# Voter: 2:
#
# Menu:
# 1. Candidate A
# 2. Candidate B
# 3. Candidate C
# Enter vote for candidate : 2
# Vote Recorded for Candidate B.
#
#
# Voter: 3:
#
# Menu:
# 1. Candidate A
# 2. Candidate B
# 3. Candidate C
# Enter vote for candidate : 1
# Vote Recorded for Candidate A.
#
# Final Result:
# Candidate A: 1 votes
# Candidate B: 2 votes
# Candidate C: 1 votes
